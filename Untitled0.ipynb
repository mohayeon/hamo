# %% [markdown]
# <a href="https://colab.research.google.com/github/mohayeon/hamo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data", header=None)
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']

feat1 = 'petal_length'
feat2 = 'petal_width'

plt.figure(figsize=(8, 6))
for cls in df['class'].unique():
    df_cls = df[df['class'] == cls]
    plt.scatter(df_cls[feat1], df_cls[feat2], label=cls)
plt.xlabel(feat1)
plt.ylabel(feat2)
plt.legend()
plt.show()
